# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimentional(1-column)

# %%
colours = pd.Series(["Red", "Blue", "White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2- dimentional
car_data = pd.DataFrame({"car make" : series, "colour": colours})
car_data
# Out:
#   car make colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# personal Example
colours1 = ["Red", "Blue", "Green"]

humans = pd.DataFrame({
    "names": ["Ajiboye", "Adeoye", "Kehinde"],
    "colours": colours1
})
# takes in  dictionary 
humans
# Out:
#      names colours
# 0  Ajiboye     Red
# 1   Adeoye    Blue
# 2  Kehinde   Green

# %%
colours1
# Out:
# ['Red', 'Blue', 'Green']

# %%
# Import data
car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#    sale_id      make     model  year  price_usd  mileage_km transmission  \
# 0        1    Toyota   Corolla  2015       9000      120000    Automatic
# 1        2     Honda     Civic  2018      12000       90000    Automatic
# 2        3      Ford     Focus  2016       7500      150000       Manual
# 3        4   Hyundai   Elantra  2017       8800      110000    Automatic
# 4        5       BMW  3 Series  2019      23000       60000    Automatic
# 5        6  Mercedes   C-Class  2020      28000       45000    Automatic
#
#   fuel_type   sold_date
# 0    Petrol  2024-01-10
# 1    Petrol  2024-02-05
# 2    Diesel  2024-02-18
# 3    Petrol  2024-03-02
# 4    Petrol  2024-03-15
# 5    Petrol  2024-03-20

# %% [raw]
# # Exporting a dataframe
# car_sales.to_csv("exported-car-sales.csv")

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'car_data.xlsx',
#  'car_sales.csv',
#  'env',
#  'heart_disease_sample.csv',
#  'Introduction-to-pandas.ipynb',
#  'Untitled.ipynb']

# %%
import glob

glob.glob("**/exported-car-sales.csv", recursive=True)
# Out:
# []

# %%
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'car_data.xlsx',
#  'car_sales.csv',
#  'env',
#  'exported-car-sales.csv',
#  'heart_disease_sample.csv',
#  'Introduction-to-pandas.ipynb',
#  'Untitled.ipynb']

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#    sale_id      make     model  year  price_usd  mileage_km transmission  \
# 0        1    Toyota   Corolla  2015       9000      120000    Automatic
# 1        2     Honda     Civic  2018      12000       90000    Automatic
# 2        3      Ford     Focus  2016       7500      150000       Manual
# 3        4   Hyundai   Elantra  2017       8800      110000    Automatic
# 4        5       BMW  3 Series  2019      23000       60000    Automatic
# 5        6  Mercedes   C-Class  2020      28000       45000    Automatic
#
#   fuel_type   sold_date
# 0    Petrol  2024-01-10
# 1    Petrol  2024-02-05
# 2    Diesel  2024-02-18
# 3    Petrol  2024-03-02
# 4    Petrol  2024-03-15
# 5    Petrol  2024-03-20

# %% [markdown]
# # Describe data

# %%
# Attribute
car_sales.dtypes
# Out:
# sale_id          int64
# make            object
# model           object
# year             int64
# price_usd        int64
# mileage_km       int64
# transmission    object
# fuel_type       object
# sold_date       object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['sale_id', 'make', 'model', 'year', 'price_usd', 'mileage_km',
#        'transmission', 'fuel_type', 'sold_date'],
#       dtype='object')

# %%
car_sales_column
